// %%
:dep notebook = { path = "." }
use notebook::*;

let mut signal = 
    BufferedInput::new(synth::sin(SampleRate::new(44100), 220., 0.), 1024)
    .unwrap();

plot_period(signal.next().unwrap())
// Out:
// <div style=""><svg width="640" height="480" viewBox="0 0 640 480" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="640" height="480" opacity="1" fill="#FFFFFF" stroke="none"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="429" x2="50" y2="20"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="62" y1="429" x2="62" y2="20"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="74" y1="429" x2="74" y2="20"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="86" y1="429" x2="86" y2="20"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="99" y1="429" x2="99" y2="20"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="111" y1="429" x2="111" y2="20"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="123" y1="429" x2="123" y2="20"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="135" y1="429" x2="135" y2="20"/>
// ...
